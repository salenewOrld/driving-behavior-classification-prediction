# %%
# %load_ext autoreload
# %autoreload 2

# %%
#df['Class'].value_counts()

# %%
#unique_values = df.nunique()

# calculate the percentage of unique values for each column
#percent_unique = unique_values / len(df) * 100

# print the percentage of unique values for each column
#print(percent_unique)

# %%
#sample = df.sample()

# %%
#print(20 * df.shape[0] / 100)

# %%
#sample = df.sample(729)

# %%
#sample

# %%
#sample_statistics = sample.describe().transpose()

# Calculate summary statistics for the population dataset
#population_statistics = df.describe().transpose()

# Compare the sample statistics with population statistics
#comparison = sample_statistics.merge(population_statistics, how='inner', left_index=True, right_index=True)

#print(comparison)

# %%
#sample_statistics

# %%
#population_statistics

# %%
#from scipy.stats import ttest_ind

# %%
#t_statistic, p_value = ttest_ind(sample_statistics['mean'], population_statistics['mean'])
#print(p_value)

# %%
#t_statistic, p_value = ttest_ind(sample_statistics['std'], population_statistics['std'])
#print(p_value)

# %%
#t_statistic, p_value = ttest_ind(sample_statistics['25%'], population_statistics['25%'])
#print(p_value)

# %%
#t_statistic, p_value = ttest_ind(sample_statistics['50%'], population_statistics['50%'])
#print(p_value)

# %%
#t_statistic, p_value = ttest_ind(sample_statistics['75%'], population_statistics['75%'])
#print(p_value)

# %%
#t_statistic, p_value = ttest_ind(sample_statistics['max'], population_statistics['max'])
#print(p_value)

# %%
#from scipy.stats import zscore

#z_scores = zscore(sample_statistics)

# %%
#z_scores

# %%
#from scipy.stats import mannwhitneyu

#def mann_whitney_u_test(data1, data2):
    
#    return u_statistic, p_value

# %%
#u_statistic, p_value = mannwhitneyu(sample_statistics['mean'], population_statistics['mean'])
#print(p_value)

# %%
#u_statistic, p_value = mannwhitneyu(sample_statistics['std'], population_statistics['std'])
#print(p_value)

# %%
#u_statistic, p_value = mannwhitneyu(sample_statistics['min'], population_statistics['min'])
#print(p_value)

# %%
#u_statistic, p_value = mannwhitneyu(sample_statistics['25%'], population_statistics['25%'])
#print(p_value)

# %%
#u_statistic, p_value = mannwhitneyu(sample_statistics['50%'], population_statistics['50%'])
#print(p_value)

# %%
#u_statistic, p_value = mannwhitneyu(sample_statistics['75%'], population_statistics['75%'])
#print(p_value)

# %%
#u_statistic, p_value = mannwhitneyu(sample_statistics['max'], population_statistics['max'])
#print(p_value)

# %%
#u_statistic, p_value = mannwhitneyu(sample_statistics['count'], population_statistics['count'])
#print(p_value)

# %%
#if df.sample(frac=1, random_state=1).equals(df):
#    print("Sample was selected randomly.")
#else:
#    print("Sample was selected with bias.")

# %%
import sys
sys.path.append('/Users/salene/Documents/GitHub/driving-behavior-classification-prediction/scripts')

# %%
# !pip3 install numpy
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.23.0)
#
# [notice] A new release of pip available: 22.2.2 -> 23.0
# [notice] To update, run: pip3 install --upgrade pip

# %%
from visualization import Visualization

# %%
vis = Visualization('/Users/salene/Documents/GitHub/driving-behavior-classification-prediction/datasets/driving-behavior/train_motion_data.csv', interpreter='Python', save=True)
# Out:
# Requirement already satisfied: seaborn in /opt/homebrew/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: scipy>=1.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: numpy>=1.15 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in /opt/homebrew/anaconda3/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/lib/python3.9/site-packages (1.21.5)

# %%
param = {
    'y' : vis.df['AccX'],
    'x' : vis.df['Class']
}
print(vis.distribution(param, graph_type='violin'))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
param = {
    'y' : vis.df['AccY'],
    'x' : vis.df['Class']
}
print(vis.distribution(param, graph_type='violin'))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
param = {
    'y' : vis.df['AccZ'],
    'x' : vis.df['Class']
}
print(vis.distribution(param, graph_type='violin'))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
param = {
    'y' : vis.df['GyroX'],
    'x' : vis.df['Class']
}
print(vis.distribution(param, graph_type='violin'))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
param = {
    'y' : vis.df['GyroY'],
    'x' : vis.df['Class']
}
print(vis.distribution(param, graph_type='violin'))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
param = {
    'y' : vis.df['GyroZ'],
    'x' : vis.df['Class']
}
print(vis.distribution(param, graph_type='violin'))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
param = {
    'y' : vis.df['GyroZ'],
    'x' : vis.df['Class']
}
print(vis.boxplot(param))
# Out:
# None

# %%
param = {
    'x' : vis.df['Class']
}
print(vis.histogram(param))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
param = {
    'x' : vis.df['AccX']
}
print(vis.histogram(param))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
param = {
    'x' : vis.df['AccX'],
    'y' : vis.df['GyroX']
}
graph = vis.joint(param)

# %%
print(vis.pairplot())
# Out:
# <seaborn.axisgrid.PairGrid object at 0x141198610>

# %%
param = {
    'x': vis.df['AccX']
}
vis.probplot(param)
# Out:
# ((array([-3.55332385, -3.31289896, -3.18012099, ...,  3.18012099,
#           3.31289896,  3.55332385]),
#   array([-4.636523 , -4.132884 , -3.7373357, ...,  4.8323727,  4.933154 ,
#           4.9855475])),
#  (0.9779492268551896, 0.040466917630340174, 0.9914413348501393))

# %%
param = {
    'x': vis.df['AccY']
}
vis.probplot(param)
# Out:
# ((array([-3.55332385, -3.31289896, -3.18012099, ...,  3.18012099,
#           3.31289896,  3.55332385]),
#   array([-4.6997952, -3.7307277, -3.7300625, ...,  3.6508338,  4.058062 ,
#           4.245151 ])),
#  (0.8959974282953189, -0.0734181548025522, 0.9910551929436464))

# %%
param = {
    'x': vis.df['AccZ']
}
vis.probplot(param)
# Out:
# ((array([-3.55332385, -3.31289896, -3.18012099, ...,  3.18012099,
#           3.31289896,  3.55332385]),
#   array([-7.143998 , -4.188234 , -4.0968165, ...,  4.906192 ,  4.95432  ,
#           5.1717386])),
#  (0.9735077943359642, 0.008271385866760524, 0.9875323651653333))

# %%
param = {
    'x': vis.df['GyroX']
}
vis.probplot(param)
# Out:
# ((array([-3.55332385, -3.31289896, -3.18012099, ...,  3.18012099,
#           3.31289896,  3.55332385]),
#   array([-0.7518224 , -0.70661837, -0.5581781 , ...,  0.57009   ,
#           0.6666067 ,  0.8492554 ])),
#  (0.06208211856927571, 0.0015927086780241485, 0.9270438174425614))

# %%
param = {
    'x': vis.df['GyroY']
}
vis.probplot(param)
# Out:
# ((array([-3.55332385, -3.31289896, -3.18012099, ...,  3.18012099,
#           3.31289896,  3.55332385]),
#   array([-1.5870279, -1.2907583, -1.2907583, ...,  0.8393288,  1.255328 ,
#           1.6798794])),
#  (0.11486911094955812, -0.0012730272123353684, 0.9094987206664531))

# %%
param = {
    'x': vis.df['GyroZ']
}
vis.probplot(param)
# Out:
# ((array([-3.55332385, -3.31289896, -3.18012099, ...,  3.18012099,
#           3.31289896,  3.55332385]),
#   array([-1.2364676 , -0.96218914, -0.9011026 , ...,  0.76289433,
#           1.0060188 ,  1.1905    ])),
#  (0.10205799717377122, 0.007949043222923152, 0.8815326855848741))

# %%
import representativeness_testing as rt

# %%
dss = rt.DescriptiveSummaryStatsAnalysis('/usr/src/datasets/driving-behavior/train_motion_data.csv')

# %%
param = {
    'percentiles' : [.25, .50, .75],
    'include' : 'all',
    'datetime_is_numeric' : True
}
dss.descriptive(param)
# Out:
#                AccX         AccY         AccZ        GyroX        GyroY  \
# count   3644.000000  3644.000000  3644.000000  3644.000000  3644.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       0.040467    -0.073418     0.008271     0.001593    -0.001273
# std        0.985653     0.903408     0.985061     0.066918     0.126205
# min       -4.636523    -4.699795    -7.143998    -0.751822    -1.587028
# 25%       -0.550695    -0.592540    -0.558464    -0.028558    -0.053756
# 50%        0.003931    -0.080833     0.002262     0.001985    -0.001833
# 75%        0.595987     0.452401     0.556157     0.031918     0.051313
# max        4.985548     4.245151     5.171739     0.849255     1.679879
#
#               GyroZ Class     Timestamp
# count   3644.000000  3644  3.644000e+03
# unique          NaN     3           NaN
# top             NaN  SLOW           NaN
# freq            NaN  1331           NaN
# mean       0.007949   NaN  3.582707e+06
# std        0.115687   NaN  6.421479e+02
# min       -1.236468   NaN  3.581629e+06
# 25%       -0.029398   NaN  3.582121e+06
# 50%        0.002978   NaN  3.582702e+06
# 75%        0.040852   NaN  3.583270e+06
# max        1.190500   NaN  3.583791e+06

# %%
param = {
    'column' : 'AccX'
}
dss.summary(param)
# Out:
# *********| Summary statistical of AccX |**********
# -----------------| Mean of AccX |----------------- : 0.0404669176303404
# ----------------| Median of AccX |---------------- : 0.0039310455
# ----------| Standard deviation of AccX |---------- : 0.9856534778545649
# ---------------| Variance of AccX |--------------- : 0.9715127784067994
# ------------| Minimum value of AccX |------------- : -4.636523
# ------------| Maximum value of AccX |------------- : 4.9855475
# -------| Count of non-null values in AccX |------- : 3644
# ---------| Count of null values in AccX |--------- : 0
# -----------------| Sum of AccX |------------------ : 147.46144784496002

# %%
param = {
    'column' : 'AccY'
}
dss.summary(param)
# Out:
# *********| Summary statistical of AccY |**********
# -----------------| Mean of AccY |----------------- : -0.07341815480255204
# ----------------| Median of AccY |---------------- : -0.08083267499999999
# ----------| Standard deviation of AccY |---------- : 0.9034079208584462
# ---------------| Variance of AccY |--------------- : 0.8161458714697806
# ------------| Minimum value of AccY |------------- : -4.6997952
# ------------| Maximum value of AccY |------------- : 4.245151
# -------| Count of non-null values in AccY |------- : 3644
# ---------| Count of null values in AccY |--------- : 0
# -----------------| Sum of AccY |------------------ : -267.53575610049995

# %%
param = {
    'column' : 'AccZ'
}
dss.summary(param)
# Out:
# *********| Summary statistical of AccZ |**********
# -----------------| Mean of AccZ |----------------- : 0.008271385866760713
# ----------------| Median of AccZ |---------------- : 0.00226163865
# ----------| Standard deviation of AccZ |---------- : 0.9850608692131377
# ---------------| Variance of AccZ |--------------- : 0.9703449160549426
# ------------| Minimum value of AccZ |------------- : -7.143998
# ------------| Maximum value of AccZ |------------- : 5.1717386
# -------| Count of non-null values in AccZ |------- : 3644
# ---------| Count of null values in AccZ |--------- : 0
# -----------------| Sum of AccZ |------------------ : 30.140930098475977

# %%
param = {
    'column' : 'GyroX'
}
dss.summary(param)
# Out:
# *********| Summary statistical of GyroX |*********
# ----------------| Mean of GyroX |----------------- : 0.001592708678024148
# ---------------| Median of GyroX |---------------- : 0.001985312
# ---------| Standard deviation of GyroX |---------- : 0.06691773602595644
# --------------| Variance of GyroX |--------------- : 0.004477983394839588
# ------------| Minimum value of GyroX |------------ : -0.7518224
# ------------| Maximum value of GyroX |------------ : 0.8492554
# ------| Count of non-null values in GyroX |------- : 3644
# --------| Count of null values in GyroX |--------- : 0
# -----------------| Sum of GyroX |----------------- : 5.80383042272

# %%
param = {
    'column' : 'GyroY'
}
dss.summary(param)
# Out:
# *********| Summary statistical of GyroY |*********
# ----------------| Mean of GyroY |----------------- : -0.0012730272123353482
# ---------------| Median of GyroY |---------------- : -0.0018325958
# ---------| Standard deviation of GyroY |---------- : 0.12620487750885595
# --------------| Variance of GyroY |--------------- : 0.015927671107025337
# ------------| Minimum value of GyroY |------------ : -1.5870279
# ------------| Maximum value of GyroY |------------ : 1.6798794
# ------| Count of non-null values in GyroY |------- : 3644
# --------| Count of null values in GyroY |--------- : 0
# -----------------| Sum of GyroY |----------------- : -4.638911161749999

# %%
param = {
    'column' : 'GyroZ'
}
dss.summary(param)
# Out:
# *********| Summary statistical of GyroZ |*********
# ----------------| Mean of GyroZ |----------------- : 0.007949043222923157
# ---------------| Median of GyroZ |---------------- : 0.002977968
# ---------| Standard deviation of GyroZ |---------- : 0.11568674290457477
# --------------| Variance of GyroZ |--------------- : 0.013383422483869182
# ------------| Minimum value of GyroZ |------------ : -1.2364676
# ------------| Maximum value of GyroZ |------------ : 1.1905
# ------| Count of non-null values in GyroZ |------- : 3644
# --------| Count of null values in GyroZ |--------- : 0
# -----------------| Sum of GyroZ |----------------- : 28.966313504332003

# %%
dss.execute()
# Out:
#                AccX         AccY         AccZ        GyroX        GyroY  \
# count   3644.000000  3644.000000  3644.000000  3644.000000  3644.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       0.040467    -0.073418     0.008271     0.001593    -0.001273
# std        0.985653     0.903408     0.985061     0.066918     0.126205
# min       -4.636523    -4.699795    -7.143998    -0.751822    -1.587028
# 25%       -0.550695    -0.592540    -0.558464    -0.028558    -0.053756
# 50%        0.003931    -0.080833     0.002262     0.001985    -0.001833
# 75%        0.595987     0.452401     0.556157     0.031918     0.051313
# max        4.985548     4.245151     5.171739     0.849255     1.679879
#
#               GyroZ Class     Timestamp
# count   3644.000000  3644  3.644000e+03
# unique          NaN     3           NaN
# top             NaN  SLOW           NaN
# freq            NaN  1331           NaN
# mean       0.007949   NaN  3.582707e+06
# std        0.115687   NaN  6.421479e+02
# min       -1.236468   NaN  3.581629e+06
# 25%       -0.029398   NaN  3.582121e+06
# 50%        0.002978   NaN  3.582702e+06
# 75%        0.040852   NaN  3.583270e+06
# max        1.190500   NaN  3.583791e+06
# *********| Summary statistical of AccX |**********
# -----------------| Mean of AccX |----------------- : 0.0404669176303404
# ----------------| Median of AccX |---------------- : 0.0039310455
# ----------| Standard deviation of AccX |---------- : 0.9856534778545649
# ---------------| Variance of AccX |--------------- : 0.9715127784067994
# ------------| Minimum value of AccX |------------- : -4.636523
# ------------| Maximum value of AccX |------------- : 4.9855475
# -------| Count of non-null values in AccX |------- : 3644
# ---------| Count of null values in AccX |--------- : 0
# -----------------| Sum of AccX |------------------ : 147.46144784496002
#
#
# *********| Summary statistical of AccY |**********
# -----------------| Mean of AccY |----------------- : -0.07341815480255204
# ----------------| Median of AccY |---------------- : -0.08083267499999999
# ----------| Standard deviation of AccY |---------- : 0.9034079208584462
# ---------------| Variance of AccY |--------------- : 0.8161458714697806
# ------------| Minimum value of AccY |------------- : -4.6997952
# ------------| Maximum value of AccY |------------- : 4.245151
# -------| Count of non-null values in AccY |------- : 3644
# ---------| Count of null values in AccY |--------- : 0
# -----------------| Sum of AccY |------------------ : -267.53575610049995
#
#
# *********| Summary statistical of AccZ |**********
# -----------------| Mean of AccZ |----------------- : 0.008271385866760713
# ----------------| Median of AccZ |---------------- : 0.00226163865
# ----------| Standard deviation of AccZ |---------- : 0.9850608692131377
# ---------------| Variance of AccZ |--------------- : 0.9703449160549426
# ------------| Minimum value of AccZ |------------- : -7.143998
# ------------| Maximum value of AccZ |------------- : 5.1717386
# -------| Count of non-null values in AccZ |------- : 3644
# ---------| Count of null values in AccZ |--------- : 0
# -----------------| Sum of AccZ |------------------ : 30.140930098475977
#
#
# *********| Summary statistical of GyroX |*********
# ----------------| Mean of GyroX |----------------- : 0.001592708678024148
# ---------------| Median of GyroX |---------------- : 0.001985312
# ---------| Standard deviation of GyroX |---------- : 0.06691773602595644
# --------------| Variance of GyroX |--------------- : 0.004477983394839588
# ------------| Minimum value of GyroX |------------ : -0.7518224
# ------------| Maximum value of GyroX |------------ : 0.8492554
# ------| Count of non-null values in GyroX |------- : 3644
# --------| Count of null values in GyroX |--------- : 0
# -----------------| Sum of GyroX |----------------- : 5.80383042272
#
#
# *********| Summary statistical of GyroY |*********
# ----------------| Mean of GyroY |----------------- : -0.0012730272123353482
# ---------------| Median of GyroY |---------------- : -0.0018325958
# ---------| Standard deviation of GyroY |---------- : 0.12620487750885595
# --------------| Variance of GyroY |--------------- : 0.015927671107025337
# ------------| Minimum value of GyroY |------------ : -1.5870279
# ------------| Maximum value of GyroY |------------ : 1.6798794
# ------| Count of non-null values in GyroY |------- : 3644
# --------| Count of null values in GyroY |--------- : 0
# -----------------| Sum of GyroY |----------------- : -4.638911161749999
#
#
# *********| Summary statistical of GyroZ |*********
# ----------------| Mean of GyroZ |----------------- : 0.007949043222923157
# ---------------| Median of GyroZ |---------------- : 0.002977968
# ---------| Standard deviation of GyroZ |---------- : 0.11568674290457477
# --------------| Variance of GyroZ |--------------- : 0.013383422483869182
# ------------| Minimum value of GyroZ |------------ : -1.2364676
# ------------| Maximum value of GyroZ |------------ : 1.1905
# ------| Count of non-null values in GyroZ |------- : 3644
# --------| Count of null values in GyroZ |--------- : 0
# -----------------| Sum of GyroZ |----------------- : 28.966313504332003
#
#
# *******| Summary statistical of Timestamp |*******
# --------------| Mean of Timestamp |--------------- : 3582706.7598792533
# -------------| Median of Timestamp |-------------- : 3582701.5
# -------| Standard deviation of Timestamp |-------- : 642.147946677827
# ------------| Variance of Timestamp |------------- : 412353.98542254936
# ----------| Minimum value of Timestamp |---------- : 3581629
# ----------| Maximum value of Timestamp |---------- : 3583791
# ----| Count of non-null values in Timestamp |----- : 3644
# ------| Count of null values in Timestamp |------- : 0
# ---------------| Sum of Timestamp |--------------- : 13055383433
